# %%
import requests

# %%
response = requests.get('https://download.medicaid.gov/data/nadac-national-average-drug-acquisition-cost-02-23-2022.csv')

# %%
response
# Out:
# <Response [200]>

# %%
response.text

# %%
import json

# json.dumps(response.headers, indent=4)
print(json.dumps(dict(response.headers), indent=4))
# Out:
# {
#     "Accept-Ranges": "bytes",
#     "ETag": "\"21e5da10502c6b843790a76a95bad2ab:1645558364.87734\"",
#     "Last-Modified": "Tue, 22 Feb 2022 19:32:44 GMT",
#     "Vary": "Accept-Encoding",
#     "Content-Encoding": "gzip",
#     "Date": "Wed, 02 Mar 2022 00:32:03 GMT",
#     "Transfer-Encoding": "chunked",
#     "Connection": "keep-alive, Transfer-Encoding",
#     "Content-Type": "application/octet-stream",
#     "content-disposition": "attachment",
#     "Strict-Transport-Security": "max-age=31536000"
# }

# %%
import pandas as pd

# %%
data = pd.read_csv('https://download.medicaid.gov/data/nadac-national-average-drug-acquisition-cost-02-23-2022.csv')

# %%
data
# Out:
#                        NDC Description          NDC  NADAC_Per_Unit  \
# 0       12HR NASAL DECONGEST ER 120 MG  24385005452         0.29366
# 1       12HR NASAL DECONGEST ER 120 MG  70000047501         0.29366
# 2       24H NASAL ALLERGY 55 MCG SPRAY  46122038576         0.78092
# 3       24HR ALLERGY(LEVOCETIRZN) 5 MG  70000036201         0.19147
# 4       24HR ALLERGY(LEVOCETIRZN) 5 MG  70000036202         0.19147
# ...                                ...          ...             ...
# 199115    ZUMANDIMINE 3 MG-0.03 MG TAB  59651003085         0.23909
# 199116                 ZYLET EYE DROPS  24208035805        56.36985
# 199117            ZYPREXA 10 MG TABLET      2411730        22.05325
# 199118            ZYPREXA 15 MG TABLET      2441530        33.16391
# 199119            ZYPREXA 20 MG TABLET      2442030        44.19089
#
#        Effective_Date Pricing_Unit Pharmacy_Type_Indicator OTC  \
# 0          12/22/2021           EA                     C/I   Y
# ...
