# %%
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt

# Data from https://www.kaggle.com/wduckett/californiaddsexpenditures?select=californiaDDSDataV2.csv

# %%
california = pd.read_csv('/data/californiaDDSDataV2.csv')

# %%
california
# Out:
#         Id Age Cohort  Age  Gender  Expenditures           Ethnicity
# 0    10210   13 to 17   17  Female          2113  White not Hispanic
# 1    10409   22 to 50   37    Male         41924  White not Hispanic
# 2    10486     0 to 5    3    Male          1454            Hispanic
# 3    10538   18 to 21   19  Female          6400            Hispanic
# 4    10568   13 to 17   13    Male          4412  White not Hispanic
# ..     ...        ...  ...     ...           ...                 ...
# 995  99622        51+   86  Female         57055  White not Hispanic
# 996  99715   18 to 21   20    Male          7494            Hispanic
# 997  99718   13 to 17   17  Female          3673          Multi Race
# 998  99791    6 to 12   10    Male          3638            Hispanic
# 999  99898   22 to 50   23    Male         26702  White not Hispanic
#
# [1000 rows x 6 columns]

# %%
sns.boxplot(x='Ethnicity', y='Expenditures', data=california)

# %%
sns.catplot(x='Ethnicity', y='Expenditures', data=california, aspect=30/8)

# %%
sns.catplot(x='Ethnicity', y='Expenditures', data=california, aspect=30/8, hue='Age Cohort')

# %%
pd.options.display.float_format = '{:,.0f}'.format
california.pivot_table(index='Age Cohort', columns='Ethnicity', aggfunc='mean', values='Expenditures')
# Out:
# Ethnicity   American Indian  Asian  Black  Hispanic  Multi Race  \
# Age Cohort
# 0 to 5                  nan  1,502  1,083     1,393       1,735
# 13 to 17              3,726  3,509  4,522     3,955       3,972
# 18 to 21                nan  9,598  8,847     9,960       9,309
# 22 to 50             28,205 39,581 40,573    40,924      38,619
# 51+                  56,911 54,623 54,010    55,585         nan
# 6 to 12                 nan  2,165  2,476     2,312       2,076
#
# Ethnicity   Native Hawaiian  Other  White not Hispanic
# Age Cohort
# 0 to 5                  nan    nan               1,367
# 13 to 17                nan  3,316               3,904
# 18 to 21                nan    nan              10,133
# 22 to 50             39,103    nan              40,188
# 51+                  50,141    nan              52,670
# 6 to 12                 nan    nan               2,052

# %%
sns.violinplot(california, x='Ethnicity', y='Age')
# Out:
# /opt/tljh/user/lib/python3.6/site-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-12-b429bb0a78d4> in <module>
# ----> 1 sns.violinplot(california, x='Ethnicity', y='Age')
#
# /opt/tljh/user/lib/python3.6/site-packages/seaborn/_decorators.py in inner_f(*args, **kwargs)
#      44             )
#      45         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46         return f(**kwargs)
#      47     return inner_f
#      48
#
# ...

# %%
california.pivot_table(index='Age Cohort', columns='Ethnicity', aggfunc='count', values='Expenditures')
# Out:
# Ethnicity   American Indian  Asian  Black  Hispanic  Multi Race  \
# Age Cohort
# 0 to 5                  nan      8      3        44           7
# 13 to 17                  1     20     12       103           7
# 18 to 21                nan     41      9        78           2
# 22 to 50                  1     29     17        43           1
# 51+                       2     13      7        17         nan
# 6 to 12                 nan     18     11        91           9
#
# Ethnicity   Native Hawaiian  Other  White not Hispanic
# Age Cohort
# 0 to 5                  nan    nan                  20
# 13 to 17                nan      2                  67
# 18 to 21                nan    nan                  69
# 22 to 50                  2    nan                 133
# 51+                       1    nan                  66
# 6 to 12                 nan    nan                  46

# %%
sns.pairplot(california)
